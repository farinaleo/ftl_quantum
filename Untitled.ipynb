# %% [markdown]
# ## EXERCICE 1 - TOKEN

# %%
from qiskit_ibm_provider import IBMProvider
provider = IBMProvider(token='1294a6887cf22e5d1443b81cdbfe27e7106f6094a684995d737cd1dc25889f20539cbb1aaf72a5ecd7e52599de253756593dfa3f941d14342a49fcf6135cb356')

print("Simulated quantum computers:")
s_backends = provider.backends(simulator=True)
for simulator in s_backends:
    status = simulator.status()
    print("     ", simulator.name, " has currently ", status.pending_jobs, " jobs in queue")

print("\n")

print("Real quantum computers:")
r_backends = provider.backends(simulator=False)
for simulator in r_backends:
    status = simulator.status()
    print("     ", simulator.name, " has currently ", status.pending_jobs, " jobs in queue with ", simulator.num_qubits, " qubits")
# Out:
# Simulated quantum computers:
#       simulator_extended_stabilizer  has currently  0  jobs in queue
#       simulator_mps  has currently  0  jobs in queue
#       simulator_statevector  has currently  0  jobs in queue
#       simulator_stabilizer  has currently  0  jobs in queue
#       ibmq_qasm_simulator  has currently  0  jobs in queue
#
#
# Real quantum computers:
#       ibm_brisbane  has currently  1152  jobs in queue with  127  qubits
#       ibm_kyoto  has currently  6  jobs in queue with  127  qubits
#       ibm_osaka  has currently  19  jobs in queue with  127  qubits

# %%
pip install qiskit_ibm_runtime

# %% [markdown]
# ## EXERCICE 2 - SUPERPOSITION

# %%
import qiskit
from qiskit.quantum_info import SparsePauliOp
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_ibm_runtime import QiskitRuntimeService, EstimatorV2 as Estimator
from qiskit_aer import AerSimulator
import matplotlib.pyplot as plt


qc = QuantumCircuit(1)

# Apply Hadamard gate to create superposition
qc.h(0)
# Draw the circuit
print("Quantum Circuit:")
print(qc.draw())
qc.measure_all()



aersim = AerSimulator()
result_ideal = aersim.run(qc, shots=500).result()
data = result_ideal.get_counts(0)

total = sum(data.values())
probabilities = {key: value/total for key, value in data.items()}

plt.bar(probabilities.keys(), probabilities.values())

for category, prob in probabilities.items():
    plt.text(category, prob, str(probabilities[category]), ha='center', va='bottom')

plt.xlabel('Categories')
plt.ylabel('Probability')
plt.title('Histogram of Probabilities')
plt.grid(axis = 'y', linestyle = '--', linewidth = 1.5)
plt.show()

qc.draw("mpl")
# Out:
# Quantum Circuit:
#    ┌───┐
# q: ┤ H ├
#    └───┘

# %% [markdown]
# ## EXERCICE 3 - ENTANGLEMENT

# %%
import qiskit
from qiskit.quantum_info import SparsePauliOp
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_ibm_runtime import QiskitRuntimeService, EstimatorV2 as Estimator
from qiskit_aer import AerSimulator
import matplotlib.pyplot as plt


qc = QuantumCircuit(2)

# Apply gates
qc.h(0)
qc.cx(0, 1)

# Draw the circuit
print("Quantum Circuit:")
print(qc.draw())
qc.draw("mpl")
qc.measure_all()



aersim = AerSimulator()
result_ideal = aersim.run(qc, shots=500).result()
data = result_ideal.get_counts(0)

total = sum(data.values())
probabilities = {key: value/total for key, value in data.items()}

plt.bar(probabilities.keys(), probabilities.values())

for category, prob in probabilities.items():
    plt.text(category, prob, str(probabilities[category]), ha='center', va='bottom')

plt.xlabel('Categories')
plt.ylabel('Probability')
plt.title('Histogram of Probabilities')
plt.grid(axis = 'y', linestyle = '--', linewidth = 1.5)
plt.show()

print(qc.draw())
qc.draw("mpl")
# Out:
# Quantum Circuit:
#      ┌───┐
# q_0: ┤ H ├──■──
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├
#           └───┘
#         ┌───┐      ░ ┌─┐
#    q_0: ┤ H ├──■───░─┤M├───
#         └───┘┌─┴─┐ ░ └╥┘┌─┐
#    q_1: ─────┤ X ├─░──╫─┤M├
#              └───┘ ░  ║ └╥┘
# meas: 2/══════════════╩══╩═
#                       0  1

# %% [markdown]
# ## EXERCICE 4 - QUANTUM NOISE

# %%
import qiskit
from qiskit.quantum_info import SparsePauliOp
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_ibm_runtime import QiskitRuntimeService, EstimatorV2 as Estimator
from qiskit_aer import AerSimulator
import matplotlib.pyplot as plt


qc = QuantumCircuit(2)

# Apply gates
qc.h(0)
qc.cx(0, 1)

# Draw the circuit
print("Quantum Circuit:")
print(qc.draw())
qc.draw("mpl")
qc.measure_all()

# aersim = AerSimulator()
# result_ideal = aersim.run(qc, shots=500).result()
# data = result_ideal.get_counts(0)
service = QiskitRuntimeService(channel="ibm_quantum", token="1294a6887cf22e5d1443b81cdbfe27e7106f6094a684995d737cd1dc25889f20539cbb1aaf72a5ecd7e52599de253756593dfa3f941d14342a49fcf6135cb356")
backend = service.least_busy(simulator=False, operational=True)
result_ideal = backend.run(qc, shots=500).result()
data = result_ideal.get_counts(0)


from matplotlib import pyplot as plt
 
data = observables_labels
values = pub_result.data.evs
 
errors = pub_result.data.ensemble_standard_error
 
plt.errorbar(observables_labels, values, yerr=errors, fmt="o")

print(qc.draw())
qc.draw("mpl")

# %% [markdown]
# # 'optimized' version

# %%
import qiskit
from qiskit.quantum_info import SparsePauliOp
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_ibm_runtime import QiskitRuntimeService, EstimatorV2 as Estimator
from qiskit_aer import AerSimulator
import matplotlib.pyplot as plt

print("Start")
qc = QuantumCircuit(2)

# Apply gates
qc.h(0)
qc.cx(0, 1)

# Draw the circuit
print("Quantum Circuit:")
print(qc.draw())
qc.draw("mpl")
qc.measure_all()

# aersim = AerSimulator()
# result_ideal = aersim.run(qc, shots=500).result()
# data = result_ideal.get_counts(0)
service = QiskitRuntimeService(channel="ibm_quantum", token="1294a6887cf22e5d1443b81cdbfe27e7106f6094a684995d737cd1dc25889f20539cbb1aaf72a5ecd7e52599de253756593dfa3f941d14342a49fcf6135cb356")
# backend = service.least_busy(simulator=False, operational=True)
backend = service.get_backend('ibm_osaka')
pm = generate_preset_pass_manager(backend=backend, optimization_level=3)
isa_circuit = pm.run(qc)
 
isa_circuit.draw('mpl', idle_wires=False)
result_ideal = backend.run(isa_circuit, shots=500).result()
data = result_ideal.get_counts(0)


from matplotlib import pyplot as plt
 
data = observables_labels
values = pub_result.data.evs
 
errors = pub_result.data.ensemble_standard_error
 
plt.errorbar(observables_labels, values, yerr=errors, fmt="o")

print(qc.draw())
qc.draw("mpl")
# Out:
# Start
# Quantum Circuit:
#      ┌───┐
# q_0: ┤ H ├──■──
#      └───┘┌─┴─┐
# q_1: ─────┤ X ├
#           └───┘
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[101], line 31
#      28 isa_circuit = pm.run(qc)
#      30 isa_circuit.draw('mpl', idle_wires=False)
# ---> 31 result_ideal = backend.run(isa_circuit, shots=500).result()
#      32 data = result_ideal.get_counts(0)
#      35 from matplotlib import pyplot as plt
#
# File /sgoinfre/goinfre/Perso/gtouzali/ftl_quantum/lib/python3.10/site-packages/qiskit_ibm_runtime/runtime_job.py:155, in RuntimeJob.result(self, timeout, decoder)
#     140 """Return the results of the job.
#     141
#     142 Args:
#    (...)
#     152     RuntimeInvalidStateError: If the job was cancelled, and attempting to retrieve result.
#     153 """
#     154 _decoder = decoder or self._final_result_decoder
# --> 155 self.wait_for_final_state(timeout=timeout)
#     156 if self._status == JobStatus.ERROR:
#     157     error_message = self._reason if self._reason else self._error_message
#
# File /sgoinfre/goinfre/Perso/gtouzali/ftl_quantum/lib/python3.10/site-packages/qiskit_ibm_runtime/runtime_job.py:338, in RuntimeJob.wait_for_final_state(self, timeout)
#     335     self._ws_client_future.result(timeout)
#     336 # poll for status after stream has closed until status is final
#     337 # because status doesn't become final as soon as stream closes
# --> 338 status = self.status()
#     339 while status not in JOB_FINAL_STATES:
#     340     elapsed_time = time.time() - start_time
#
# File /sgoinfre/goinfre/Perso/gtouzali/ftl_quantum/lib/python3.10/site-packages/qiskit_ibm_runtime/runtime_job.py:194, in RuntimeJob.status(self)
#     188 def status(self) -> JobStatus:
#     189     """Return the status of the job.
#     190
#     191     Returns:
#     192         Status of this job.
#     193     """
# --> 194     self._set_status_and_error_message()
#     195     return self._status
#
# File /sgoinfre/goinfre/Perso/gtouzali/ftl_quantum/lib/python3.10/site-packages/qiskit_ibm_runtime/base_runtime_job.py:224, in BaseRuntimeJob._set_status_and_error_message(self)
#     222 """Fetch and set status and error message."""
#     223 if not self.in_final_state():
# --> 224     response = self._api_client.job_get(job_id=self.job_id())
#     225     self._set_status(response)
#     226     self._set_error_message(response)
#
# File /sgoinfre/goinfre/Perso/gtouzali/ftl_quantum/lib/python3.10/site-packages/qiskit_ibm_runtime/api/clients/runtime.py:111, in RuntimeClient.job_get(self, job_id, exclude_params)
#     102 def job_get(self, job_id: str, exclude_params: bool = True) -> Dict:
#     103     """Get job data.
#     104
#     105     Args:
#    (...)
#     109         JSON response.
#     110     """
# --> 111     response = self._api.program_job(job_id).get(exclude_params=exclude_params)
#     112     logger.debug("Runtime job get response: %s", response)
#     113     return response
#
# File /sgoinfre/goinfre/Perso/gtouzali/ftl_quantum/lib/python3.10/site-packages/qiskit_ibm_runtime/api/rest/program_job.py:59, in ProgramJob.get(self, exclude_params)
#      57 if exclude_params:
#      58     payload["exclude_params"] = "true"
# ---> 59 return self.session.get(self.get_url("self"), params=payload).json(cls=RuntimeDecoder)
#
# File /sgoinfre/goinfre/Perso/gtouzali/ftl_quantum/lib/python3.10/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     968             raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#     975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# File /sgoinfre/goinfre/Perso/gtouzali/ftl_quantum/lib/python3.10/site-packages/simplejson/__init__.py:533, in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, allow_nan, **kw)
#     531 if allow_nan:
#     532     kw['allow_nan'] = True
# --> 533 return cls(encoding=encoding, **kw).decode(s)
#
# File /sgoinfre/goinfre/Perso/gtouzali/ftl_quantum/lib/python3.10/site-packages/qiskit_ibm_runtime/utils/json.py:332, in RuntimeDecoder.__init__(self, *args, **kwargs)
#     331 def __init__(self, *args: Any, **kwargs: Any):
# --> 332     super().__init__(object_hook=self.object_hook, *args, **kwargs)
#     333     self.__parameter_vectors: Dict[str, Tuple[ParameterVector, set]] = {}
#     334     self.__read_parameter_expression = (
#     335         functools.partial(
#     336             _read_parameter_expression_v3,
#    (...)
#     340         else _read_parameter_expression
#     341     )
#
# TypeError: JSONDecoder.__init__() got an unexpected keyword argument 'encoding'
